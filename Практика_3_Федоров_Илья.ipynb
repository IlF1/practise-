# %% [markdown]
# <a href="https://colab.research.google.com/github/IlF1/practise-/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_3_%D0%A4%D0%B5%D0%B4%D0%BE%D1%80%D0%BE%D0%B2_%D0%98%D0%BB%D1%8C%D1%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ФИО

# %%
Федоров Илья Вадимович

# %% [markdown]
# **Во всей практике нельзя применять библиотеки предоставляющие готовые решения!**

# %% [markdown]
# # **Задача 1.**

# %% [markdown]
# Типы данных Напишите программу на Python, которая принимает список чисел в качестве входных данных от пользователя, а затем выводит сумму, среднее значение и максимальное значение из списка.
#
# ***Нельзя использовать: len(), min(), max(), average(), sum()***
#
# Дано:
# ```
# 1 2 3 4 5 6 7
# ```
# Вывод:
#
# ```
# Сумма чисел: 28
# Среднее арифм.: 4.0
# Максимальное значение: 7
# ```

# %%
a=input("введи список чисел: ")
aa=a.split()
sm=0
for element in aa:
  sm=sm+int(element)
print(sm)
k=0
for e in aa:
  k=k+1
print(sm/k)
ma=-1000000000
for ele in aa:
  if int(ele)>int(ma):
    ma=ele
print(ma)
# Out:
# введи список чисел: 12 23 -123
# -88
# -29.333333333333332
# 23

# %% [markdown]
# # **Задача 2.**

# %% [markdown]
# Напишите программу на Python, которая принимает список слов в качестве входных данных от пользователя, а затем распечатывает список в обратном порядке.
#
# Ввод:
#
# ```
# апельсин мандарин яблоко
# ```
#
# Вывод:
#
# ```
# яблоко мандарин апельсин
# ```

# %%
s=str(input("введи список слов: "))
print(*reversed(s.split()))
# Out:
# введи список слов: оцршгуц ргшршг
# ргшршг оцршгуц

# %% [markdown]
# # **Задача 3**

# %% [markdown]
# Простой чат-бот
# Создайте простого чат-бота, который отвечает на основные запросы пользователей. Программа должна использовать условные выражения для определения намерений пользователя и последующего соответствующего ответа.
#
# Чат бот может:
#
# - помогать складывать числа
# - подсказывать фильм, музыку и тд (из заранее созданного списка)
# - создавать список дел (а также выводить его, обновлять, очищать)
#
# Интерфейс чат-бота на ваше усмотрение, это могут быть как заранее определенные команды, так и к примеру вызов команды по номеру
#
# *Реализовать без использования функций*
#
# Пример:
#
# Ввод:
#
# ```
# Олег, какую мызыку посоветуешь?
# ```
#
# Вывод:
#
# ```
# Я бы посоветовал вам: Led Zeppelin Stairway to Heaven
# ```

# %%
filmlist=["Гарри Поттер","Трансформеры","Интерстеллар","Джентельмены"]
mlist=["Lady hear me tonight - Modjo","Ocean Drive - Duke Dumont","Мир моих снов - Макс Корж"]
import random
print("Этот бот умеет: 1- складывать числа, 2- рекомендовать фильмы, 3- рекомендовать музыку, 4-создавать список дел")
u=int(input("введи номер услуги(1/2/3/4): "))
if u==1:
  s=input("Введи через пробел числа, которые нужно сложить:")
  sum=0
  ss=s.split()
  for chi in ss:
    sum=sum+int(chi)
  print(sum)
if u==2:
  print(random.choice(filmlist))
if u==3:
  print(random.choice(mlist))
if u==4:
  sp=input("введи список дел ")
  spp=sp.split()

  vizov=input("Если нужно показать список дел, введи(да), отредактировать список, введи (redact), очистить список - введи (clear)")
  if vizov == "да":
    print(spp)
  if vizov == "clear":
    print(spp.clear())
  if vizov =="redact":
    act=input("что нужно сделать со списком? Добавить дело(+)/удалить дело(-)" )
    if act =="+":
      a=input("какое дело добавляем в словарь? :")
      spp.append(a)
      print(spp)
    if act =="-":
      aa=input("какое дело убираем? : ")
      spp.remove(aa)
      print(spp)
# Out:
# Этот бот умеет: 1- складывать числа, 2- рекомендовать фильмы, 3- рекомендовать музыку, 4-создавать список дел
# введи номер услуги(1/2/3/4): 4
# введи список дел фв ошо що
# Если нужно показать список дел, введи(да), отредактировать список, введи (redact), очистить список - введи (clear)clear
# None

# %% [markdown]
# # **Задача 4.**

# %% [markdown]
# Камень, ножницы, бумага
#
# Создайте игру в Камень, ножницы, бумагу, в которой пользователь может играть против компьютера. Программа должна запросить выбор пользователя, а затем сгенерировать выбор компьютера. Затем программа должна определить победителя на основе правил игры.
#
# **Этап 1:**
#
# Определение победителя
#
# **Этап 2:**
#
# Игра до 3 побед
#
#
# Ввод для "Этап 1":
#
# ```
# Камень
# ```
#
# Вывод:
#
# ```
# Компьютер: Ножницы
# Игрок: Камень
# Победа: Игрок
# ```

# %%
ch=["камень","ножницы","бумага"]
k=[]
p=[]
import random
while len(p)<3 or len(k)<3:
  v=input("введи название фигуры, например - камень: ")
  if v!="камень" and v!="бумага" and v!="ножницы":
    print("mistake, введи верную команду")
  a=random.choice(ch)
  print(a)
  if v=="бумага" and a=="бумага":
    print("ничья")
  if  v=="бумага" and a=="камень":
    print("победа пользователя")
    p.append(1)
  if v=="бумага" and a =="ножницы":
    print("победа компьютера")
    k.append(1)
  if v=="ножницы" and a=="бумага":
    print("победа пользователя")
    p.append(1)
  if  v=="ножницы" and a=="камень":
    print("победа компьютера")
    k.append(1)
  if v=="ножницы" and a =="ножницы":
    print("ничья")
  if v=="камень" and a=="бумага":
    print("победа компьютера")
    k.append(1)
  if  v=="камень" and a=="камень":
    print("ничья")
  if v=="камень" and a =="ножницы":
    print("победа пользователя")
    p.append(1)
  if len(p)==3:
    print("ПОЛЬЗОВАТЕЛЬ ВЫИГРАЛ")
    break
  if len(k)==3:
    print("КОМПЬЮТЕР ВЫИГРАЛ")
    break
# Out:
# введи название фигуры, например - камень: камень
# камень
# ничья
# введи название фигуры, например - камень: камень
# камень
# ничья
# введи название фигуры, например - камень: камень
# бумага
# победа компьютера
# введи название фигуры, например - камень: бумага
# ножницы
# победа компьютера
# введи название фигуры, например - камень: ожницы
# mistake, введи верную команду
# камень
# введи название фигуры, например - камень: опа
# mistake, введи верную команду
# ножницы
# введи название фигуры, например - камень: камень
# ножницы
# победа пользователя
# введи название фигуры, например - камень: камень
# камень
# ничья
# введи название фигуры, например - камень: камень
# камень
# ничья
# введи название фигуры, например - камень: ножницы
# ножницы
# ничья
# введи название фигуры, например - камень: бумага
# ножницы
# победа компьютера
# КОМПЬЮТЕР ВЫИГРАЛ

# %% [markdown]
# # **Задача 5.**

# %% [markdown]
# Создайте игру "Палач" или "Виселица", в которой пользователь должен угадать слово, предлагая буквы. Программа должна выбрать случайное слово, а затем разрешить пользователю угадывать буквы. После каждого угадывания программа должна сообщать пользователю, есть ли в слове буква или нет.
#
# **Этап 1**
# Создать саму игру
#
# **Этап 2:**
# Ввести подсчет количества очков и ограничения на попытки
#
# **Этап 3:** Добавить возможность сразу угадать слово

# %%
print("Уважаемый пользователь, в нашей игре важно соблюдать регистр вписанных букв и команд. Буквы писать строчными, целые слова тоже. Регистр команд смотри по ходу игры =)")
import random
spisok=["дом","апельсины","ананас","мама","кукуруза","яблоко"]
slovo=random.choice(spisok)
d=len(slovo)
print("длина слова =",d)
points=[]
bukv=[]
mistakess=10
sch=0
print("количество ошибок =",mistakess)
while len(points)!=d:
  print("если вы знаете слово целиком - введите (ДА), иначе введи (НЕТ)  и продолжай/начинай угадывать буквы")
  kom=input("Знаешь слово?" )
  if kom=="ДА":
    sll=input("введи слово ")
    if sll == slovo:
      print("cлово угадано =", sll)
      break
    else:
      mistakess=mistakess-1
      print("слово угадано неверно, осталось попыток =", mistakess)
  if kom=='НЕТ':
    b=input("введи букву: ")
    if b in slovo and b not in bukv:
      kol=slovo.count(b)
      print("вы угадали букву, количество этой буквы в слове =",kol)
      sch=sch+kol#cуммируем количество всех угаданных букв, чтобы потом проверить равенство количества и длины слова
      bukv.append(b)
      if sch==d:
        print("Вы угадали слово",slovo)
        break
    else:
      mistakess=mistakess-1
      print("этой буквы в слове нет, количество оставшихся жизней =",mistakess)
    if mistakess<1:
      print("slovo ne ugadano, vi повешаны")
      break
  else:
    print("Вы ввели неверную команду, повторите попытку")

    #znak=input("если вы знаете слово целиком, то введите - да, иначе введите - нет:")
    #if znak=="да":
      #word=input("введи слово: -")
      #if word==slovo:
        #print("Вы угадали слово=",word)
        #break
      #else:
        #mistakess=mistakess-1
        #print("Неверное слово, осталось", mistakess, "попыток")
    #if znak !="да" and znak!="нет":
      #print("вы ввели неверную комманду")
# Out:
# Уважаемый пользователь, в нашей игре важно соблюдать регистр вписанных букв и команд. Буквы писать строчными, целые слова тоже. Регистр команд смотри по ходу игры =)
# длина слова = 3
# количество ошибок = 10
# если вы знаете слово целиком - введите (ДА), иначе введи (НЕТ)  и продолжай/начинай угадывать буквы
# Знаешь слово?НЕТ
# введи букву: д
# вы угадали букву, количество этой буквы в слове = 1
# если вы знаете слово целиком - введите (ДА), иначе введи (НЕТ)  и продолжай/начинай угадывать буквы
# Знаешь слово?ДА
# введи слово кулема
# слово угадано неверно, осталось попыток = 9
# Вы ввели неверную команду, повторите попытку
# если вы знаете слово целиком - введите (ДА), иначе введи (НЕТ)  и продолжай/начинай угадывать буквы
# Знаешь слово?ДА
# введи слово пизда
# слово угадано неверно, осталось попыток = 8
# Вы ввели неверную команду, повторите попытку
# если вы знаете слово целиком - введите (ДА), иначе введи (НЕТ)  и продолжай/начинай угадывать буквы
# Знаешь слово?ДА
# ...

# %% [markdown]
# # **Дополнительно: Задача 6.**

# %% [markdown]
# **Цифра на определенном месте:**
#
# Последовательно записан натуральный ряд чисел.
#
# Какая цифра стоит в N позиции
#
#
# Вввод:
#
# ```
# Введите номер позиции: 1234567890
# ```
#
# Вывод:
#
# ```
# 8
# ```

# %%
p=str(input("введи ряд чисел"))
i=int(input("введи номер позиции"))
print(p[i-1])
# Out:
# введи ряд чисел1736786387624
# введи номер позиции4
# 6
